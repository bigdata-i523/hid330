# %%
# Raw DataSet a sample
import pandas as pd
import numpy as np
import datetime as datetime
dfAQ = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep = ',')
dfAQ.head(15)
# Out:
#             CBSA  CBSA Code        Date  AQI  Category Defining Parameter  \
# 0   Aberdeen, SD      10100  2016-01-01   16      Good              PM2.5
# 1   Aberdeen, SD      10100  2016-01-04   31      Good              PM2.5
# 2   Aberdeen, SD      10100  2016-01-07   76  Moderate              PM2.5
# 3   Aberdeen, SD      10100  2016-01-10   34      Good              PM2.5
# 4   Aberdeen, SD      10100  2016-01-13   44      Good              PM2.5
# 5   Aberdeen, SD      10100  2016-01-16   17      Good              PM2.5
# 6   Aberdeen, SD      10100  2016-01-19   53  Moderate              PM2.5
# 7   Aberdeen, SD      10100  2016-01-22   30      Good              PM2.5
# 8   Aberdeen, SD      10100  2016-01-25   36      Good              PM2.5
# 9   Aberdeen, SD      10100  2016-01-29   16      Good              PM2.5
# 10  Aberdeen, SD      10100  2016-01-31   25      Good              PM2.5
# 11  Aberdeen, SD      10100  2016-02-03   18      Good              PM2.5
# ...

# %%
# Number of AQI records for each parameter
import pandas as pd
import datetime as datetime
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI[['CBSA', 'Date', 'Category', 'Defining Parameter']]
dfAQI['Defining Parameter'].value_counts()
# Out:
# Ozone    91649
# PM2.5    66631
# PM10      7908
# SO2       5882
# NO2       1759
# CO         113
# Name: Defining Parameter, dtype: int64

# %%
# Composite Dataset by selecting columns of interest
import pandas as pd
import datetime as datetime
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI[['CBSA', 'Date', 'Category', 'AQI', 'Defining Parameter']]
dfAQI.head(10)
# Out:
#            CBSA       Date  Category  AQI Defining Parameter
# 0  Aberdeen, SD 2016-01-01      Good   16              PM2.5
# 1  Aberdeen, SD 2016-01-04      Good   31              PM2.5
# 2  Aberdeen, SD 2016-01-07  Moderate   76              PM2.5
# 3  Aberdeen, SD 2016-01-10      Good   34              PM2.5
# 4  Aberdeen, SD 2016-01-13      Good   44              PM2.5
# 5  Aberdeen, SD 2016-01-16      Good   17              PM2.5
# 6  Aberdeen, SD 2016-01-19  Moderate   53              PM2.5
# 7  Aberdeen, SD 2016-01-22      Good   30              PM2.5
# 8  Aberdeen, SD 2016-01-25      Good   36              PM2.5
# 9  Aberdeen, SD 2016-01-29      Good   16              PM2.5

# %%
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI.groupby(['CBSA','Defining Parameter']). AQI.agg(['mean', 'max'])
dfAQI =  (dfAQI.sort_values(by='mean', ascending=False))
dfAQI.tail(10)
# Out:
#                                                        mean  max
# CBSA                           Defining Parameter
# College Station-Bryan, TX      SO2                 1.753425   20
# Wilmington, NC                 SO2                 1.437500    3
# Rochester, MN                  SO2                 1.000000    1
# Corning, NY                    SO2                 1.000000    1
# Jamestown-Dunkirk-Fredonia, NY SO2                 1.000000    1
# Kapaa, HI                      SO2                 0.500000    1
# Gulfport-Biloxi-Pascagoula, MS SO2                 0.500000    1
# Seneca, SC                     SO2                 0.461538    3
# Fayetteville, NC               SO2                 0.375000    1
# Madison, WI                    SO2                 0.000000    0

# %%
# 
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI.groupby(['CBSA','Defining Parameter']). AQI.agg(['mean', 'max'])
dfAQI =  (dfAQI.sort_values(by='mean', ascending=False))
dfAQI.head(10)
# Out:
#                                                                       mean  \
# CBSA                                        Defining Parameter
# Hilo, HI                                    SO2                 151.787535
# Riverside-San Bernardino-Ontario, CA        Ozone               126.528497
# Lansing-East Lansing, MI                    SO2                 123.000000
# San Juan-Carolina-Caguas, PR                SO2                 119.611111
# Bishop, CA                                  PM10                117.657895
# Durango, CO                                 NO2                 109.000000
# Riverside-San Bernardino-Ontario, CA        PM10                108.195122
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD SO2                 107.000000
# Los Angeles-Long Beach-Anaheim, CA          Ozone               105.458101
# Minneapolis-St. Paul-Bloomington, MN-WI     SO2                 105.000000
#
#                                                                 max
# ...

# %%
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
# %matplotlib inline
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI.groupby(['Defining Parameter']). AQI.mean().plot(kind='bar', title= 'CBSA Average AQI for Criteria Pollutants')

# %%
# Box Plot For No of days of each Category
import pandas as pd
import datetime as datetime
import matplotlib.pyplot as plt
# %matplotlib inline
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI[['CBSA', 'Date', 'Category', 'Defining Parameter']]
pldata = dfAQI.groupby(['CBSA','Category','Defining Parameter']).count()
pldata.boxplot(column = 'Date',by='Category', manage_xticks =True, figsize =(15, 10), patch_artist = True)
# Out:
# C:\Users\janum_000\Anaconda2\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
import pandas as pd
import datetime as datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
dfAQI = pd.read_csv("https://aqs.epa.gov/aqsweb/airdata/daily_aqi_by_cbsa_2016.zip", sep= ',')
dfAQI['Date'] = pd.to_datetime(dfAQI.Date)
dfAQI = dfAQI[['CBSA', 'Date', 'AQI', 'Category', 'Defining Parameter','Number of Sites Reporting']]
dfAQI['Defining Parameter'].value_counts()
sns.FacetGrid(dfAQI, hue ='Defining Parameter', size=10)\
    .map(plt.scatter, 'Number of Sites Reporting', 'AQI')\
    .add_legend()
